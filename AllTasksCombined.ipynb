# %% [markdown]
# ### Task 1:
# #### Indentifying and Importing Essential Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Task 2:
# #### Data Loading and Overview

# %% [markdown]
# a.) Load the dataset from a file

# %%
data = pd.read_excel (r'Superstore.xls')

# %% [markdown]
# b.) Look at the first 5 records of the data

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# c.) Print the columns contained in the data

# %%
for col in data.columns: 
    print(col)
# Out:
# Row ID
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# Country
# City
# State
# Postal Code
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit

# %% [markdown]
# d.) Print the attributes like count, mean, max, min, standard deviation etc

# %%
print("Count:")
print(data.count())

print("\n\nMean:")
print(data.mean())

print("\n\nMax:")
print(data.max())

print("\n\nMin:")
print(data.min())

print("\n\nStandard Deviation:")
print(data.std())
# Out:
# Count:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64
#
#
# Mean:
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64
#
#
# Max:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                      2017-12-30 00:00:00
# Ship Date                       2018-01-05 00:00:00
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                       22638.5
# Quantity                                         14
# Discount                                        0.8
# Profit                                      8399.98
# dtype: object
#
#
# Min:
# Row ID                                                           1
# Order ID                                            CA-2014-100006
# Order Date                                     2014-01-03 00:00:00
# Ship Date                                      2014-01-07 00:00:00
# Ship Mode                                              First Class
# Customer ID                                               AA-10315
# Customer Name                                        Aaron Bergman
# Segment                                                   Consumer
# Country                                              United States
# City                                                      Aberdeen
# State                                                      Alabama
# Postal Code                                                   1040
# Region                                                     Central
# Product ID                                         FUR-BO-10000112
# Category                                                 Furniture
# Sub-Category                                           Accessories
# Product Name     "While you Were Out" Message Book, One Form pe...
# Sales                                                        0.444
# Quantity                                                         1
# Discount                                                         0
# Profit                                                    -6599.98
# dtype: object
#
#
# Standard Deviation:
# Row ID          2885.163629
# Postal Code    32063.693350
# Sales            623.245101
# Quantity           2.225110
# Discount           0.206452
# Profit           234.260108
# dtype: float64

# %% [markdown]
# e.) Find out are there any missing or null values in the data for all columns.

# %%
data.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
rows x 21 columns]

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# No missing or null values

# %% [markdown]
# ### Task 3:
# #### Find out the per unit price from the data

# %% [markdown]
# a.) Convert data time field into pandas time object

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])
data["Ship Date"] = pd.to_datetime(data["Ship Date"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null datetime64[ns]
# Ship Date        9994 non-null datetime64[ns]
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %% [markdown]
# b.) Find out the price per unit from the data and create a column for it in
# the same data

# %%
data['Price Per Unit'] = data["Sales"] / data["Quantity"]

# %% [markdown]
# ### Task 4:
# #### Find out the monthy revenue and analyze the findings

# %% [markdown]
# a.) Create a column with Year and month field only give a suitable name to it.

# %%
order_date_year = data["Order Date"].dt.year
data['Year'] = pd.DataFrame(order_date_year)
order_date_month = data["Order Date"].dt.month
data['Month'] = pd.DataFrame(order_date_month)

monthly_data = data['Order Date'].dt.strftime('%Y-%m')
monthly_data
# Out:
# 0       2016-11
# 1       2016-11
# 2       2016-06
# 3       2015-10
# 4       2015-10
# 5       2014-06
# 6       2014-06
# 7       2014-06
# 8       2014-06
# 9       2014-06
# 10      2014-06
# 11      2014-06
# 12      2017-04
# 13      2016-12
# 14      2015-11
# 15      2015-11
# 16      2014-11
# 17      2014-05
# 18      2014-08
# 19      2014-08
# 20      2014-08
# 21      2016-12
# 22      2016-12
# 23      2017-07
# 24      2015-09
# 25      2016-01
# 26      2016-01
# 27      2015-09
# 28      2015-09
# 29      2015-09
#          ...
# 9964    2016-12
# 9965    2016-12
# 9966    2016-12
# 9967    2017-12
# 9968    2017-12
# 9969    2017-12
# 9970    2015-06
# 9971    2015-06
# 9972    2016-09
# 9973    2016-12
# 9974    2016-12
# 9975    2016-12
# 9976    2016-12
# 9977    2016-12
# 9978    2016-12
# 9979    2016-12
# 9980    2015-09
# 9981    2017-08
# 9982    2016-09
# 9983    2016-09
# 9984    2015-05
# 9985    2015-05
# 9986    2016-09
# 9987    2017-11
# 9988    2017-11
# 9989    2014-01
# 9990    2017-02
# 9991    2017-02
# 9992    2017-02
# 9993    2017-05
# Name: Order Date, Length: 9994, dtype: object

# %% [markdown]
# b.) Create a separate dataset from the data which will have two columns, one which is created in step 'a' of this task and second the monthly sales/revenue

# %%
monthly_sales = data.groupby(['Year','Month'])['Sales'].sum()
newdata = pd.DataFrame(monthly_sales)
#newdata

newdata1 = data.groupby(['Year','Month'])['Profit'].sum()
newdata1 = pd.DataFrame(newdata1)
#newdata2

# %%
result_month = newdata.merge(newdata1, left_index=True, right_index=True)
result_month.reset_index(inplace=True)
result_month['Date'] = pd.to_datetime(result_month[['Year','Month']].assign(DAY=1))
tempmonth = result_month
result_month = result_month.drop(columns=["Year","Month"])

# %% [markdown]
# c.) Plot this dataset

# %%
result_month.plot(x='Date',y=['Sales','Profit'])

# %% [markdown]
# ### Task 5:
# #### Find out the yearly revenue and analyze the findings

# %% [markdown]
# a.) Create a column with Year field only give a suitable name to it

# %%
yearly_data = data['Order Date'].dt.strftime('%Y')
yearly_data
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
# 5       2014
# 6       2014
# 7       2014
# 8       2014
# 9       2014
# 10      2014
# 11      2014
# 12      2017
# 13      2016
# 14      2015
# 15      2015
# 16      2014
# 17      2014
# 18      2014
# 19      2014
# 20      2014
# 21      2016
# 22      2016
# 23      2017
# 24      2015
# 25      2016
# 26      2016
# 27      2015
# 28      2015
# 29      2015
#         ...
# 9964    2016
# 9965    2016
# 9966    2016
# 9967    2017
# 9968    2017
# 9969    2017
# 9970    2015
# 9971    2015
# 9972    2016
# 9973    2016
# 9974    2016
# 9975    2016
# 9976    2016
# 9977    2016
# 9978    2016
# 9979    2016
# 9980    2015
# 9981    2017
# 9982    2016
# 9983    2016
# 9984    2015
# 9985    2015
# 9986    2016
# 9987    2017
# 9988    2017
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: Order Date, Length: 9994, dtype: object

# %% [markdown]
# b.) Create a separate dataset from the data which will have two columns,
# one which is created in step a of this task and second the yearly sales/revenue

# %%
yearly_sales = data.groupby(['Year'])['Sales'].sum()
newdata = pd.DataFrame(yearly_sales)
#newdata

newdata1 = data.groupby(['Year'])['Profit'].sum()
newdata1 = pd.DataFrame(newdata1)
#newdata2

result_year = newdata.merge(newdata1, left_index=True, right_index=True)
result_year.reset_index(inplace=True)
result_year
# Out:
#    Year        Sales      Profit
# 0  2014  484247.4981  49543.9741
# 1  2015  470532.5090  61618.6037
# 2  2016  609205.5980  81795.1743
# 3  2017  733215.2552  93439.2696

# %% [markdown]
# c.) Plot this dataset

# %%
result_year.plot.bar(x='Year',y=['Sales','Profit'])

# %% [markdown]
# d.) Describe your analysis for the yearly revenue observations.

# %%
result_year['% Diff Sales'] = result_year.groupby('Year')['Sales'].pct_change()
result_year['% Diff Profit'] = result_year.groupby('Year')['Profit'].pct_change()
result_year
# Out:
#    Year        Sales      Profit  % Diff Sales  % Diff Profit
# 0  2014  484247.4981  49543.9741           NaN            NaN
# 1  2015  470532.5090  61618.6037     -0.028322       0.243715
# 2  2016  609205.5980  81795.1743      0.294715       0.327443
# 3  2017  733215.2552  93439.2696      0.203560       0.142357

# %% [markdown]
# ##### Inferences:
#
# 1.) The Sales Revenue has been increasing since 2014, with an exception of 2015, while the Profits have also been increasing.
#
# 2.) The Sales for the Year 2015 had a lower turnout by 0.02833% as compared to 2014. While for the next years, the turnout is higher than the previous.
#
# 3.) While the sales for the Year 2015 were lower compared to 2014, the profit margin was higher.

# %% [markdown]
# ### Task 6:
# #### Finding out the monthy growth rate and analyse the findings.

# 42  2017      7   45264.4160   6952.6212 2017-07-01     -0.145660
# 43  2017      8   63120.8880   9040.9557 2017-08-01      0.394492
# 44  2017      9   87866.6520  10991.5556 2017-09-01      0.392038
# 45  2017     10   77776.9232   9275.2755 2017-10-01     -0.114830
# 46  2017     11  118447.8250   9690.1037 2017-11-01      0.522917
# 47  2017     12   83829.3188   8483.3468 2017-12-01     -0.292268
#
#     % Diff Profit
# 0             NaN
# 1       -0.648065
# 2       -0.421634
# 3        5.995440
# 4       -0.215007
# 5        0.817106
# 6       -1.169090
# 7       -7.319923
# 8        0.565990
# 9       -0.585949
# 10       1.694731
# 11      -0.033206
# 12      -1.365223
# 13      -1.857618
# 14       2.458640
# 15      -0.569723
# 16       0.114716
# 17      -0.285422
# 18      -0.014063
# 19       0.628574
# 20       0.532759
# 21      -0.656802
# 22       3.427820
# 23      -0.357347
# 24      -0.647644
# 25       0.771643
# 26      -0.278267
# 27      -0.175570
# 28       1.908893
# 29      -0.451593
# 30      -0.066837
# 31      -0.534824
# 32       3.523930
# 33       0.741209
# 34      -0.753040
# 35       3.458612
# 36      -0.600765
# 37      -0.773981
# 38       8.140682
# 39      -0.936734
# 40       5.795940
# 41       0.296528
# 42      -0.154525
# 43       0.300367
# 44       0.215752
# 45      -0.156145
# 46       0.044724
# 47      -0.124535

# %% [markdown]
# b.) Find out the maximum monthly growth rate

# %%
max_month_growth = tempmonth['% Diff Sales'].max()
max_month_index = tempmonth['% Diff Sales'].idxmax()
max_month = tempmonth.iloc[max_month_index]
print("Growth Rate is maximum for the Year:", max_month['Year'], "and Month:", max_month['Month'])
# Out:
# Growth Rate is maximum for the Year: 2014 and Month: 3

# %% [markdown]
# c.) Plot the findings

# %%
tempmonth['Date'] = pd.to_datetime(tempmonth[['Year','Month']].assign(DAY=1))
tempmonth.plot(x='Date',y=['% Diff Sales'])

# %% [markdown]
# d.) Describe the findings

# %%
max_month
# Out:
# Year                            2014
# Month                              3
# Sales                          55691
# Profit                        498.73
# Date             2014-03-01 00:00:00
# % Diff Sales                 11.3213
# % Diff Profit              -0.421634
# Name: 2, dtype: object

# %% [markdown]
# The growth rate (% difference in annual sales) for March 2014 was 11.3213% which was the highest growth rate observed in the dataset.

# %% [markdown]
# ### Task 7:
# #### Finding out the most and least sold product ID

# %% [markdown]
# a.) Create a new dataset including the product IDs and total quantities sold for that ID

# %%
prod_id = data.groupby(['Product ID'])['Quantity'].sum()
prod_id = pd.DataFrame(prod_id)
prod_id.sort_values(by=['Product ID'], inplace=True)
prod_id = prod_id.reset_index()
prod_id
# Out:
#            Product ID  Quantity
# 0     FUR-BO-10000112         9
# 1     FUR-BO-10000330        10
# 2     FUR-BO-10000362        14
# 3     FUR-BO-10000468        21
# 4     FUR-BO-10000711        12
# 5     FUR-BO-10000780        22
# 6     FUR-BO-10001337        28
# 7     FUR-BO-10001519        22
# 8     FUR-BO-10001567         3
# 9     FUR-BO-10001601        10
# 10    FUR-BO-10001608        30
# 11    FUR-BO-10001619         6
# 12    FUR-BO-10001798        12
# 13    FUR-BO-10001811        26
# 14    FUR-BO-10001918        10
# 15    FUR-BO-10001972        37
# 16    FUR-BO-10002202         3
# 17    FUR-BO-10002206         1
# 18    FUR-BO-10002213        42
# 19    FUR-BO-10002268        16
# 20    FUR-BO-10002545        35
# 21    FUR-BO-10002598        19
# 22    FUR-BO-10002613        27
# 23    FUR-BO-10002824         6
# 24    FUR-BO-10002853         9
# 25    FUR-BO-10002916        15
# 26    FUR-BO-10003034        18
# 27    FUR-BO-10003159        19
# 28    FUR-BO-10003272        21
# 29    FUR-BO-10003404         8
# ...               ...       ...
# 1832  TEC-PH-10004100        27
# 1833  TEC-PH-10004120        13
# 1834  TEC-PH-10004165        34
# 1835  TEC-PH-10004188        18
# 1836  TEC-PH-10004241         4
# 1837  TEC-PH-10004345        21
# 1838  TEC-PH-10004348         5
# 1839  TEC-PH-10004389        11
# 1840  TEC-PH-10004434        12
# 1841  TEC-PH-10004447        31
# 1842  TEC-PH-10004522        11
# 1843  TEC-PH-10004531        24
# 1844  TEC-PH-10004536        12
# 1845  TEC-PH-10004539        24
# 1846  TEC-PH-10004586        17
# 1847  TEC-PH-10004614        28
# 1848  TEC-PH-10004667        26
# 1849  TEC-PH-10004700        14
# 1850  TEC-PH-10004774        16
# 1851  TEC-PH-10004830         4
# 1852  TEC-PH-10004833        26
# 1853  TEC-PH-10004875         2
# 1854  TEC-PH-10004896        20
# 1855  TEC-PH-10004897        30
# 1856  TEC-PH-10004908        25
# 1857  TEC-PH-10004912        11
# 1858  TEC-PH-10004922        19
# 1859  TEC-PH-10004924         8
# 1860  TEC-PH-10004959         4
# 1861  TEC-PH-10004977        32
#
# [1862 rows x 2 columns]

# %% [markdown]
# b.) Find out the most sold product from the created dataset

# %%
most_sold_quant = prod_id['Quantity'].max()
most_sold_index = prod_id['Quantity'].idxmax()
most_sold = prod_id.iloc[most_sold_index]
most_sold
# Out:
# Product ID    TEC-AC-10003832
# Quantity                   75
# Name: 1569, dtype: object

# %% [markdown]
# ### Task 8:
# #### Finding out the customer who bought most and least from us in terms of quantity

# %% [markdown]
# a.) Create a dataset containing name and quantities bought

# %%
customer = data.groupby(['Customer ID','Customer Name'])['Quantity'].sum()
customer = pd.DataFrame(customer)
customer.sort_values(by=['Customer ID'], inplace=True)
customer = customer.reset_index()
customer
# Out:
#     Customer ID         Customer Name  Quantity
# 0      AA-10315            Alex Avila        30
# 1      AA-10375          Allen Armold        41
# 2      AA-10480          Andrew Allen        36
# 3      AA-10645         Anna Andreadi        64
# 4      AB-10015         Aaron Bergman        13
# 5      AB-10060       Adam Bellavance        56
# 6      AB-10105         Adrian Barton        73
# 7      AB-10150           Aimee Bixby        37
# 8      AB-10165           Alan Barnes        48
# 9      AB-10255  Alejandro Ballentine        39
# 10     AB-10600             Ann Blume        38
# 11     AC-10420         Alyssa Crouse        17
# 12     AC-10450               Amy Cox        43
# 13     AC-10615             Ann Chong        59
# 14     AC-10660            Anna Chung        16
# 15     AD-10180        Alan Dominguez        40
# 16     AF-10870          Art Ferguson        51
# 17     AF-10885            Art Foster        37
# 18     AG-10270       Alejandro Grove        58
# 19     AG-10300   Aleksandra Gannaway        16
# 20     AG-10330          Alex Grayson        47
# 21     AG-10390        Allen Goldenen        33
# 22     AG-10495       Andrew Gjertsen        93
# 23     AG-10525          Andy Gerbode        33
# 24     AG-10675           Anna Gayman        54
# 25     AG-10765     Anthony Garverick        20
# 26     AG-10900         Arthur Gainer        92
# 27     AH-10030         Aaron Hawkins        54
# 28     AH-10075             Adam Hart        75
# 29     AH-10120           Adrian Hane        65
# ..          ...                   ...       ...
# 763    TS-21340         Toby Swindell        51
# 764    TS-21370          Todd Sumrall        59
# 765    TS-21430           Tom Stivers        31
# 766    TS-21505            Tony Sayre        54
# 767    TS-21610          Troy Staebel        44
# 768    TS-21655         Trudy Schmidt        52
# 769    TT-21070           Ted Trevino        66
# 770    TT-21220       Thomas Thornton        55
# 771    TT-21265           Tim Taslimi         8
# 772    TT-21460         Tonja Turnell        48
# 773    TW-21025     Tamara Willingham        57
# 774    TZ-21580             Tracy Zic        30
# 775    VB-21745      Victoria Brennan        37
# 776    VD-21670     Valerie Dominguez        71
# 777    VF-21715        Vicky Freymann        35
# 778    VG-21790        Vivek Gonzalez        32
# 779    VG-21805           Vivek Grady        16
# 780    VM-21685       Valerie Mitchum        37
# 781    VM-21835         Vivian Mathis        25
# 782    VP-21730          Victor Preis        18
# 783    VP-21760      Victoria Pisteka        65
# 784    VS-21820      Vivek Sundaresam        38
# 785    VT-21700      Valerie Takahito        42
# 786    VW-21775       Victoria Wilson        77
# 787    WB-21850         William Brown       146
# 788    XP-21865          Xylona Preis       100
# 789    YC-21895        Yoseph Carroll        31
# 790    YS-21880         Yana Sorensen        58
# 791    ZC-21910      Zuschuss Carroll       105
# 792    ZD-21925    Zuschuss Donatelli        32
#
# [793 rows x 3 columns]

# %% [markdown]
# b.) Find out the customer name and quantity, who bought maximum in quantity

# %%
max_purchase_customer_quant = customer['Quantity'].max()
max_purchase_customer_index = customer['Quantity'].idxmax()
max_purchase_customer = customer.iloc[max_purchase_customer_index]
max_purchase_customer
# Out:
# Customer ID              JD-15895
# Customer Name    Jonathan Doherty
# Quantity                      150
# Name: 349, dtype: object

# %% [markdown]
# ### Task 9:
# #### Finding out the customer who bought most and least from us in terms of value

# %% [markdown]
# a.) Create a dataset containing name and sales generated by him

# %%
sales_data = data.groupby(['Customer Name'])['Sales'].sum()
sales_data = pd.DataFrame(sales_data)
sales_data = sales_data.reset_index()
sales_data
# Out:
#             Customer Name      Sales
# 0           Aaron Bergman    886.156
# 1           Aaron Hawkins   1744.700
# 2          Aaron Smayling   3050.692
# 3         Adam Bellavance   7755.620
# 4               Adam Hart   3250.337
# 5      Adam Shillingsburg   3255.310
# 6           Adrian Barton  14473.571
# 7             Adrian Hane   1735.514
# 8            Adrian Shami     58.820
# 9             Aimee Bixby    966.710
# 10            Alan Barnes   1113.838
# 11         Alan Dominguez   6106.880
# 12            Alan Haines   1587.452
# 13             Alan Hwang   4805.344
# 14      Alan Schoenberger   4260.784
# 15           Alan Shonely    584.608
# 16   Alejandro Ballentine    914.532
# 17        Alejandro Grove   2582.898
# 18       Alejandro Savely   3214.236
# 19    Aleksandra Gannaway    367.548
# 20             Alex Avila   5563.560
# 21           Alex Grayson    660.972
# 22           Alex Russell   1055.694
# 23         Alice McCarthy    814.012
# 24           Allen Armold   1056.390
# 25         Allen Goldenen    200.945
# 26       Allen Rosenblatt   2236.128
# 27          Alyssa Crouse    925.800
# 28            Alyssa Tate   1171.814
# 29                Amy Cox   5527.846
# ..                    ...        ...
# 763         Tony Molinari   1094.678
# 764            Tony Sayre   2243.274
# 765       Tracy Blumstein   4737.486
# 766         Tracy Collins    742.558
# 767         Tracy Hopkins   4234.096
# 768          Tracy Poddar   1936.640
# 769             Tracy Zic   1707.286
# 770        Troy Blackwell   1387.559
# 771          Troy Staebel   2820.424
# 772           Trudy Brown   2797.668
# 773          Trudy Glocke   2074.661
# 774         Trudy Schmidt   3368.094
# 775     Valerie Dominguez   6442.254
# 776       Valerie Mitchum   2454.866
# 777      Valerie Takahito   1736.596
# 778        Vicky Freymann    847.944
# 779          Victor Preis    993.902
# 780      Victoria Brennan   2005.596
# 781      Victoria Pisteka   3360.526
# 782       Victoria Wilson   6134.038
# 783        Vivek Gonzalez    846.010
# 784           Vivek Grady    427.372
# 785      Vivek Sundaresam   1055.981
# 786         Vivian Mathis    380.690
# 787         William Brown   6160.102
# 788          Xylona Preis   2374.658
# 789         Yana Sorensen   6720.444
# 790        Yoseph Carroll   5454.350
# 791      Zuschuss Carroll   8025.707
# 792    Zuschuss Donatelli   1493.944
#
# [793 rows x 2 columns]

# %% [markdown]
# b.) Find out the customer name and sales, who bought maximum in value

# %%
most_sales_customer_sale = sales_data['Sales'].max()
most_sales_customer_index = sales_data['Sales'].idxmax()
most_sales_customer = sales_data.iloc[most_sales_customer_index]
most_sales_customer
# Out:
# Customer Name    Sean Miller
# Sales                  25043
# Name: 686, dtype: object

# %% [markdown]
# ### Task 10:
# #### Finding out the majority and minority customer cities on basis of

# %% [markdown]
# a.) Number of Customers

# %%
cities_data_cust = data.groupby(['City'])['Customer Name'].count()
cities_data_cust = pd.DataFrame(cities_data_cust)
cities_data_cust = cities_data_cust.reset_index()
cities_data_cust = cities_data_cust.rename(columns = {"Customer Name": "No. of Customers"})
cities_data_cust
# Out:
#                   City  No. of Customers
# 0             Aberdeen                 1
# 1              Abilene                 1
# 2                Akron                21
# 3          Albuquerque                14
# 4           Alexandria                16
# 5                Allen                 4
# 6            Allentown                 7
# 7              Altoona                 2
# 8             Amarillo                10
# 9              Anaheim                27
# 10             Andover                 4
# 11           Ann Arbor                 5
# 12             Antioch                 1
# 13              Apopka                 7
# 14        Apple Valley                 9
# 15            Appleton                 2
# 16           Arlington                60
# 17   Arlington Heights                 1
# 18              Arvada                 4
# 19           Asheville                 7
# 20              Athens                 8
# 21             Atlanta                39
# 22       Atlantic City                 1
# 23              Auburn                24
# 24              Aurora                68
# 25              Austin                39
# 26            Avondale                 6
# 27         Bakersfield                16
# 28           Baltimore                43
# 29              Bangor                 5
# ..                 ...               ...
# 501            Visalia                 4
# 502               Waco                 6
# 503      Warner Robins                 2
# 504            Warwick                 5
# 505         Washington                10
# 506          Waterbury                11
# 507           Waterloo                 1
# 508          Watertown                10
# 509           Waukesha                 1
# 510             Wausau                 4
# 511         Waynesboro                10
# 512         West Allis                 2
# 513        West Jordan                 5
# 514    West Palm Beach                 3
# 515          Westfield                 6
# 516           Westland                13
# 517        Westminster                17
# 518           Wheeling                 7
# 519           Whittier                 1
# 520            Wichita                 7
# 521         Wilmington                36
# 522             Wilson                 6
# 523           Woodbury                 3
# 524           Woodland                 3
# 525          Woodstock                 5
# 526         Woonsocket                 4
# 527            Yonkers                15
# 528               York                 5
# 529            Yucaipa                 1
# 530               Yuma                 4
#
# [531 rows x 2 columns]

# %%
max_cust_city_index = cities_data_cust['No. of Customers'].idxmax()
max_cust_city = cities_data_cust.iloc[max_cust_city_index]
max_cust_city
# Out:
# City                New York City
# No. of Customers              915
# Name: 329, dtype: object

# %%
min_cust_city_index = cities_data_cust['No. of Customers'].idxmin()
min_cust_city = cities_data_cust.iloc[min_cust_city_index]
min_cust_city
# Out:
# City                Aberdeen
# No. of Customers           1
# Name: 0, dtype: object

# %% [markdown]
# b.) Sales Value

# %%
cities_data_sales = data.groupby(['City'])['Sales'].sum()
cities_data_sales = pd.DataFrame(cities_data_sales)
cities_data_sales = cities_data_sales.reset_index()
cities_data_sales
# Out:
#                   City       Sales
# 0             Aberdeen     25.5000
# 1              Abilene      1.3920
# 2                Akron   2729.9860
# 3          Albuquerque   2220.1600
# 4           Alexandria   5519.5700
# 5                Allen    290.2060
# 6            Allentown    853.2520
# 7              Altoona     20.4510
# 8             Amarillo   3773.0628
# 9              Anaheim   7986.8700
# 10             Andover    435.8500
# 11           Ann Arbor    889.2730
# 12             Antioch     19.4400
# 13              Apopka    904.5540
# 14        Apple Valley   2053.0210
# 15            Appleton   1671.3100
# 16           Arlington  20214.5320
# 17   Arlington Heights     14.1120
# 18              Arvada    503.4000
# 19           Asheville   1475.3760
# 20              Athens   1720.8100
# 21             Atlanta  17197.8400
# 22       Atlantic City     23.3600
# 23              Auburn   3155.1680
# 24              Aurora  11656.4780
# 25              Austin   6057.9820
# 26            Avondale    946.8080
# 27         Bakersfield   1377.2900
# 28           Baltimore   6156.8420
# 29              Bangor   1164.4500
# ..                 ...         ...
# 501            Visalia    318.7800
# 502               Waco    606.1072
# 503      Warner Robins    434.8000
# 504            Warwick   2426.8400
# 505         Washington   2865.0200
# 506          Waterbury   1326.0600
# 507           Waterloo     30.3200
# 508          Watertown   4044.9980
# 509           Waukesha     54.5000
# 510             Wausau    317.4800
# 511         Waynesboro   3058.7700
# 512         West Allis    250.4800
# 513        West Jordan    311.8500
# 514    West Palm Beach    141.3280
# 515          Westfield    519.7200
# 516           Westland   2057.9760
# 517        Westminster   3826.6460
# 518           Wheeling   1946.9660
# 519           Whittier    444.7680
# 520            Wichita    825.2700
# 521         Wilmington   7297.0610
# 522             Wilson    368.7320
# 523           Woodbury    607.6500
# 524           Woodland    264.6620
# 525          Woodstock   1143.9000
# 526         Woonsocket    195.5500
# 527            Yonkers   7657.6660
# 528               York    817.9780
# 529            Yucaipa     50.8000
# 530               Yuma    840.8650
#
# [531 rows x 2 columns]

# %%
max_sales_city_index = cities_data_sales['Sales'].idxmax()
max_sales_city = cities_data_sales.iloc[max_sales_city_index]
max_sales_city
# Out:
# City     New York City
# Sales           256368
# Name: 329, dtype: object

# %%
min_sales_city_index = cities_data_sales['Sales'].idxmin()
min_sales_city = cities_data_sales.iloc[min_sales_city_index]
min_sales_city
# Out:
# City     Abilene
# Sales      1.392
# Name: 1, dtype: object

# %% [markdown]
# c.) Number of quantity sold

# %%
cities_data_quant = data.groupby(['City'])['Quantity'].sum()
cities_data_quant = pd.DataFrame(cities_data_quant)
cities_data_quant = cities_data_quant.reset_index()
cities_data_quant
# Out:
#                   City  Quantity
# 0             Aberdeen         3
# 1              Abilene         2
# 2                Akron        65
# 3          Albuquerque        65
# 4           Alexandria        84
# 5                Allen        13
# 6            Allentown        20
# 7              Altoona         9
# 8             Amarillo        32
# 9              Anaheim       112
# 10             Andover        13
# 11           Ann Arbor        23
# 12             Antioch         3
# 13              Apopka        31
# 14        Apple Valley        32
# 15            Appleton        12
# 16           Arlington       259
# 17   Arlington Heights         6
# 18              Arvada        10
# 19           Asheville        28
# 20              Athens        30
# 21             Atlanta       156
# 22       Atlantic City         2
# 23              Auburn        80
# 24              Aurora       258
# 25              Austin       131
# 26            Avondale        30
# 27         Bakersfield        47
# 28           Baltimore       184
# 29              Bangor        29
# ..                 ...       ...
# 501            Visalia        20
# 502               Waco        17
# 503      Warner Robins        10
# 504            Warwick        14
# 505         Washington        40
# 506          Waterbury        33
# 507           Waterloo         4
# 508          Watertown        35
# 509           Waukesha         5
# 510             Wausau        14
# 511         Waynesboro        32
# 512         West Allis         5
# 513        West Jordan        16
# 514    West Palm Beach        11
# 515          Westfield        16
# 516           Westland        46
# 517        Westminster        50
# 518           Wheeling        27
# 519           Whittier         4
# 520            Wichita        26
# 521         Wilmington       157
# 522             Wilson        20
# 523           Woodbury        11
# 524           Woodland         7
# 525          Woodstock        31
# 526         Woonsocket        15
# 527            Yonkers        57
# 528               York        19
# 529            Yucaipa         5
# 530               Yuma        22
#
# [531 rows x 2 columns]

# %%
max_quant_city_index = cities_data_quant['Quantity'].idxmax()
max_quant_city = cities_data_quant.iloc[max_quant_city_index]
max_quant_city
# Out:
# City        New York City
# Quantity             3417
# Name: 329, dtype: object

# %%
min_quant_city_index = cities_data_quant['Quantity'].idxmin()
min_quant_city = cities_data_quant.iloc[min_quant_city_index]
min_quant_city
# Out:
# City        Elyria
# Quantity         1
# Name: 140, dtype: object

# %% [markdown]
# ### Task 11:
# #### Finding out the most and least sold product category from the store

# %% [markdown]
# a.) Value based

# %%
prod_sale = data.groupby(['Category'])['Sales'].sum()
prod_sale = pd.DataFrame(prod_sale)
prod_sale = prod_sale.reset_index()
prod_sale
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
max_prod_sale_index = prod_sale['Sales'].idxmax()
max_prod_sale = prod_sale.iloc[max_prod_sale_index]
max_prod_sale
# Out:
# Category    Technology
# Sales           836154
# Name: 2, dtype: object

# %%
min_prod_sale_index = prod_sale['Sales'].idxmin()
min_prod_sale = prod_sale.iloc[min_prod_sale_index]
min_prod_sale
# Out:
# Category    Office Supplies
# Sales                719047
# Name: 1, dtype: object

# %% [markdown]
# b.) Quantity based

# %%
prod_quant = data.groupby(['Category'])['Quantity'].sum()
prod_quant = pd.DataFrame(prod_quant)
prod_quant = prod_quant.reset_index()
prod_quant
# Out:
#           Category  Quantity
# 0        Furniture      8028
# 1  Office Supplies     22906
# 2       Technology      6939

# %%
max_prod_quant_index = prod_quant['Quantity'].idxmax()
max_prod_quant = prod_quant.iloc[max_prod_quant_index]
max_prod_quant
# Out:
# Category    Office Supplies
# Quantity              22906
# Name: 1, dtype: object

# %%
min_prod_quant_index = prod_quant['Quantity'].idxmin()
min_prod_quant = prod_quant.iloc[min_prod_quant_index]
min_prod_quant
# Out:
# Category    Technology
# Quantity          6939
# Name: 2, dtype: object

# %% [markdown]
# ### Task 12:
# #### Finding out the most and least sold product sub category from the store

# %% [markdown]
# a.) Value based

# %%
sub_prod_sales = data.groupby(['Sub-Category'])['Sales'].sum()
sub_prod_sales = pd.DataFrame(sub_prod_sales)
sub_prod_sales = sub_prod_sales.reset_index()
sub_prod_sales
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
max_sub_prod_sales_index = sub_prod_sales['Sales'].idxmax()
max_sub_prod_sales = sub_prod_sales.iloc[max_sub_prod_sales_index]
max_sub_prod_sales
# Out:
# Sub-Category    Phones
# Sales           330007
# Name: 13, dtype: object

# %%
min_sub_prod_sales_index = sub_prod_sales['Sales'].idxmin()
min_sub_prod_sales = sub_prod_sales.iloc[min_sub_prod_sales_index]
min_sub_prod_sales
# Out:
# Sub-Category    Fasteners
# Sales             3024.28
# Name: 8, dtype: object

# %% [markdown]
# b.) Quantity based

# %%
sub_prod_quant = data.groupby(['Sub-Category'])['Quantity'].sum()
sub_prod_quant = pd.DataFrame(sub_prod_quant)
sub_prod_quant = sub_prod_quant.reset_index()
sub_prod_quant
# Out:
#    Sub-Category  Quantity
# 0   Accessories      2976
# 1    Appliances      1729
# 2           Art      3000
# 3       Binders      5974
# 4     Bookcases       868
# 5        Chairs      2356
# 6       Copiers       234
# 7     Envelopes       906
# 8     Fasteners       914
# 9   Furnishings      3563
# 10       Labels      1400
# 11     Machines       440
# 12        Paper      5178
# 13       Phones      3289
# 14      Storage      3158
# 15     Supplies       647
# 16       Tables      1241

# %%
max_sub_prod_quant_index = sub_prod_quant['Quantity'].idxmax()
max_sub_prod_quant = sub_prod_quant.iloc[max_sub_prod_quant_index]
max_sub_prod_quant
# Out:
# Sub-Category    Binders
# Quantity           5974
# Name: 3, dtype: object

# %%
min_sub_prod_quant_index = sub_prod_quant['Quantity'].idxmin()
min_sub_prod_quant = sub_prod_quant.iloc[min_sub_prod_quant_index]
min_sub_prod_quant
# Out:
# Sub-Category    Copiers
# Quantity            234
# Name: 6, dtype: object

# %% [markdown]
# =============================== End =====================================
