# %%
# Preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 2:
# ## Data Loading and Overview

# %% [markdown]
# ### a.) Load the dataset from a file

# %%
data = pd.read_excel (r'Superstore.xls')

# %% [markdown]
# ### b.) Look at the first 5 records of the data

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### c.) Print the columns contained in the data

# %%
for col in data.columns: 
    print(col)
# Out:
# Row ID
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# Country
# City
# State
# Postal Code
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit

# %% [markdown]
# ### d.) Print the attributes like count, mean, max, min, standard deviation etc

# %%
Count = data.count()
Count = pd.DataFrame(Count)
Mean = data.mean()
Mean = pd.DataFrame(Mean)
Max = data.max()
Max = pd.DataFrame(Max)
Min = data.min()
Min = pd.DataFrame(Min)
Standard_Deviation = data.std()
Standard_Deviation = pd.DataFrame(Standard_Deviation)

attributes = [Count,Mean,Max,Min,Standard_Deviation]

for i in range(len(attributes)):
    Count = Count.merge(attributes[i], left_index=True, right_index=True, suffixes=(str(i),str(i+1)))
        
Count = Count.drop(columns=["00"])         
Count = Count.rename(columns={"01":"Count", "02":"Mean", "03":"Max", "04":"Min", "05":"Standard Deviation"})
attribute_data = Count
attribute_data = pd.DataFrame(attribute_data)
attribute_data
# Out:
#              Count          Mean      Max      Min  Standard Deviation
# Row ID        9994   4997.500000     9994        1         2885.163629
# Postal Code   9994  55190.379428    99301     1040        32063.693350
# Sales         9994    229.858001  22638.5    0.444          623.245101
# Quantity      9994      3.789574       14        1            2.225110
# Discount      9994      0.156203      0.8        0            0.206452
# Profit        9994     28.656896  8399.98 -6599.98          234.260108

# %% [markdown]
# ### e.) Find out are there any missing or null values in the data for all columns.

# %%
data.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# 5      False     False       False      False      False        False
# 6      False     False       False      False      False        False
# 7      False     False       False      False      False        False
# 8      False     False       False      False      False        False
# 9      False     False       False      False      False        False
# 10     False     False       False      False      False        False
# 11     False     False       False      False      False        False
# ...

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# #### No missing or null values
